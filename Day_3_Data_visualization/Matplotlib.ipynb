# %% [markdown]
# ### Introduction to Matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.available
plt.style.use('seaborn-v0_8-whitegrid')

# %%
plt.plot()
# Out:
# []

# %%
x = [1, 2, 3, 4]
y = [10, 8, 6, 9]
plt.plot(x, y, color="red")

# %% [markdown]
# ### Pyplot API VS Object-Oriented API
# * Pyplot API --> Quickly
# * OO API --> Advanced

# %%
x = np.linspace(0, 10, 1000)
plt.title("Sin(x) and Cos(x)")
plt.plot(x, np.sin(x), color="blue", linestyle="dashed", label="sin(x)")
plt.plot(x, np.cos(x), color="red", label="cos(x)")
plt.xlabel("Bien X")
plt.ylabel("Sin(x)")
plt.legend()
plt.axis("equal")
# plt.axis([0, 4, -0.9, 0.9])
# plt.xlim([0, 4])
# plt.ylim([-0.75, 0.6])
# Out:
# (-0.5, 10.5, -1.0999987378908789, 1.0999999398995657)

# %% [markdown]
# ### Object-Oriented API

# %%
#1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

#2. Setup plot
fig, ax = plt.subplots(figsize=(5,5)) #Figure size = width and height of the plot
#3. Plot the data
ax.plot(x, y)

ax.set(title="A simple plot",
      xlabel = "x_axis",
      ylabel = "y_axis")
# Out:
# [Text(0.5, 1.0, 'A simple plot'),
#  Text(0.5, 0, 'x_axis'),
#  Text(0, 0.5, 'y_axis')]

# %% [markdown]
# ## 2. Most common type of Matpotlib
# * line
# * scater
# * bar
# * hist
# * subplot()

# %%
#Create an array
x = np.linspace(0, 10, 100)
x[:5]
# Out:
# array([0.       , 0.1010101, 0.2020202, 0.3030303, 0.4040404])

# %%
#00 API plot a line chart 
fig, ax = plt.subplots()
ax.plot(x, x**3)

# %% [markdown]
# ### Scatter

# %%
#Pyplot API
plt.scatter(x, np.exp(x)) #y = e^(x)

# %%
#00 API
#Prepare New Data
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
sizes = 1000*rng.rand(100)
colors = rng.rand(100)

fig, ax = plt.subplots()
img1 = ax.scatter(x, y, s = sizes, c=colors, cmap="viridis", alpha=0.3)
fig.colorbar(img1)

# %% [markdown]
# ### 3. Bar
# * Vertical
# * Horizontal

# %%
#Prepare Data From a python dictionary
soft_drink_prices = {"Coke": 10, 
                     "Pessi": 12,
                     "Sprite": 8}
fig, ax = plt.subplots()
ax.bar(soft_drink_prices.keys(), soft_drink_prices.values())
ax.set(title="Bach Hoa Xanh's soft drink prices", xlabel="soft drink", ylabel="Price ($)")
# Out:
# [Text(0.5, 1.0, "Bach Hoa Xanh's soft drink prices"),
#  Text(0.5, 0, 'soft drink'),
#  Text(0, 0.5, 'Price ($)')]

# %%
fig, ax = plt.subplots()
ax.barh(soft_drink_prices.keys(), soft_drink_prices.values())
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ### 4. Histogram

# %%
#Prepare data
student_height = np.random.normal(170, 10, 250)
student_height
# Out:
# array([175.56227597, 178.18211884, 183.14998231, 173.84296397,
#        168.56268804, 164.36419375, 180.13098688, 179.77755171,
#        159.64647135, 181.89615514, 154.94184749, 164.25974498,
#        179.19371416, 162.03642249, 163.28131748, 173.36357759,
#        167.36556607, 152.51185114, 166.945175  , 174.60194173,
#        182.18102975, 172.82193261, 175.7050106 , 165.35423751,
#        169.47768727, 172.68593923, 172.00090354, 167.33292195,
#        149.93633204, 169.75096495, 162.84161708, 181.20305137,
#        151.24825293, 156.85290429, 163.18634792, 174.23980465,
#        179.25654431, 165.31927286, 179.92363934, 173.4806797 ,
#        161.61512174, 181.19211555, 180.99520151, 153.98735124,
#        179.27758434, 161.55400664, 159.85633398, 180.06609553,
#        175.95339634, 175.53443418, 170.42727374, 167.24822779,
#        158.79333175, 162.96309607])

# %%
#pyplot API
plt.title("Student height")
plt.hist(student_height, bins=30, edgecolor='black')
# Out:
# (array([ 3.,  6.,  4.,  5., 12., 15., 24., 28., 19., 19., 15., 21., 14.,
#         17., 14., 15.,  9.,  4.,  3.,  0.,  1.,  0.,  0.,  0.,  0.,  0.,
#          1.,  0.,  0.,  1.]),
#  array([147.95903257, 150.1350063 , 152.31098004, 154.48695378,
#         156.66292751, 158.83890125, 161.01487499, 163.19084873,
#         165.36682246, 167.5427962 , 169.71876994, 171.89474368,
#         174.07071741, 176.24669115, 178.42266489, 180.59863862,
#         182.77461236, 184.9505861 , 187.12655984, 189.30253357,
#         191.47850731, 193.65448105, 195.83045479, 198.00642852,
#         200.18240226, 202.358376  , 204.53434974, 206.71032347,
#         208.88629721, 211.06227095, 213.23824468]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# ### Subplots

# %%
# Option 1:
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

#Plot data to each axis
ax1.plot(x, x/2)
ax1.plot(x, x*2)

ax2.scatter(np.random.random(10), np.random.random(10))

ax3.bar(soft_drink_prices.keys(), soft_drink_prices.values())

ax4.hist(student_height, bins=30, edgecolor='black')
# Out:
# (array([ 3.,  6.,  4.,  5., 12., 15., 24., 28., 19., 19., 15., 21., 14.,
#         17., 14., 15.,  9.,  4.,  3.,  0.,  1.,  0.,  0.,  0.,  0.,  0.,
#          1.,  0.,  0.,  1.]),
#  array([147.95903257, 150.1350063 , 152.31098004, 154.48695378,
#         156.66292751, 158.83890125, 161.01487499, 163.19084873,
#         165.36682246, 167.5427962 , 169.71876994, 171.89474368,
#         174.07071741, 176.24669115, 178.42266489, 180.59863862,
#         182.77461236, 184.9505861 , 187.12655984, 189.30253357,
#         191.47850731, 193.65448105, 195.83045479, 198.00642852,
#         200.18240226, 202.358376  , 204.53434974, 206.71032347,
#         208.88629721, 211.06227095, 213.23824468]),
#  <BarContainer object of 30 artists>)

# %%
#Option 2:
fig, ax = plt.subplots(nrows = 2,
                      ncols = 2,
                      figsize=(10, 5))

#Plot data to each axis
ax[0,0].plot(x, x/2)
ax[0, 0].plot(x, x*2)

ax[0, 1].scatter(np.random.random(10), np.random.random(10))

ax[1, 0].bar(soft_drink_prices.keys(), soft_drink_prices.values())

ax[1, 1].hist(student_height, bins=30, edgecolor='black')
# Out:
# (array([ 3.,  6.,  4.,  5., 12., 15., 24., 28., 19., 19., 15., 21., 14.,
#         17., 14., 15.,  9.,  4.,  3.,  0.,  1.,  0.,  0.,  0.,  0.,  0.,
#          1.,  0.,  0.,  1.]),
#  array([147.95903257, 150.1350063 , 152.31098004, 154.48695378,
#         156.66292751, 158.83890125, 161.01487499, 163.19084873,
#         165.36682246, 167.5427962 , 169.71876994, 171.89474368,
#         174.07071741, 176.24669115, 178.42266489, 180.59863862,
#         182.77461236, 184.9505861 , 187.12655984, 189.30253357,
#         191.47850731, 193.65448105, 195.83045479, 198.00642852,
#         200.18240226, 202.358376  , 204.53434974, 206.71032347,
#         208.88629721, 211.06227095, 213.23824468]),
#  <BarContainer object of 30 artists>)
